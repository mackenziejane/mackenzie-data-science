# %% [markdown]
# # DS-NYC-45 | Final Project 4: Modeling Performance

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn as skl
from sklearn import ensemble, neighbors, tree, metrics

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)

# %matplotlib inline
plt.style.use('ggplot')

# %%
users = pd.read_csv(os.path.join('project_dataset', 'user_data.csv'), index_col='user_id')
res = pd.read_csv(os.path.join('project_dataset', 'reservations_data.csv'), index_col='user_id')

# %%
df = pd.concat([users, res], axis=1, join_axes=[users.index])

df.head()
# Out:
#          is_converted  lead_created_month  lead_created_day_of_week  \
# user_id
# 12                  0                   5                         4
# 14                  0                   5                         5
# 15                  1                   6                         1
# 16                  1                   7                         3
# 23                  1                   6                         1
#
#          is_paidsocial_lead  is_organic_lead  lead_msa_id  is_seo_studios  \
# user_id
# 12                        0                1          1.0               0
# 14                        0                1          1.0               0
# 15                        0                1          1.0               0
# 16                        0                1          1.0               0
# 23                        0                1          1.0               0
#
#          is_inviteafriend  is_email  is_referral  is_paidsocial  \
# user_id
# 12                      0         0            0              0
# 14                      0         0            0              0
# 15                      0         0            0              0
# 16                      0         0            0              0
# 23                      0         0            0              0
#
#         marketing_channel  is_organic  user_acquisition_month  \
# user_id
# 12              Sell Page           1                     9.0
# 14              Sell Page           1                     9.0
# 15                 Mobile           1                     9.0
# 16              Sell Page           1                     8.0
# 23              Sell Page           0                     8.0
#
#          user_acquisition_day_of_week  promo_days  lead_to_promo_days  \
# user_id
# 12                                3.0         NaN                   0
# 14                                3.0         NaN                   0
# 15                                1.0         NaN                   0
# 16                                4.0         NaN                   0
# 23                                3.0        30.0                 429
#
#          is_three_studio_visits  is_two_studio_visits  is_four_studio_visits  \
# user_id
# 12                            1                     0                      0
# 14                            1                     0                      0
# 15                            0                     1                      0
# 16                            1                     0                      0
# 23                            0                     1                      0
#
#         acquisition_plan_category    zip  is_onboarded  user_country  \
# user_id
# 12               CP Complimentary  10001             1           1.0
# 14               CP Complimentary  10009             1           1.0
# 15                        CP Base  10003             1           1.0
# 16                   CP Unlimited    NaN             1           1.0
# 23                        CP Base  30363             1           1.0
#
#          user_msa_id promo_alias parent_promo promo_category  \
# user_id
# 12               1.0    no_promo     no_promo       no_promo
# 14               1.0    no_promo     no_promo       no_promo
# 15               1.0    no_promo     no_promo       no_promo
# 16               1.0    no_promo     no_promo       no_promo
# 23               1.0      aug1fb  dollarpromo          trial
#
#          is_commitment_plan  avg_class_rating  avg_days_from_booking_to_class  \
# user_id
# 12                      NaN               NaN                             NaN
# 14                      NaN               NaN                             NaN
# 15                      NaN               NaN                             NaN
# 16                      NaN               NaN                             NaN
# 23                      0.0               5.0                            1.25
#
#          avg_peak_classes  reservations_attended_barre_count  \
# user_id
# 12                    NaN                                NaN
# 14                    NaN                                NaN
# 15                    NaN                                NaN
# 16                    NaN                                NaN
# 23                   0.75                                0.0
#
#          reservations_attended_boxing_count  \
# user_id
# 12                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 23                                      0.0
#
#          reservations_attended_cycling_count  \
# user_id
# 12                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 23                                       0.0
#
#          reservations_attended_dance_count  reservations_attended_gym_count  \
# user_id
# 12                                     NaN                              NaN
# 14                                     NaN                              NaN
# 15                                     NaN                              NaN
# 16                                     NaN                              NaN
# 23                                     1.0                              0.0
#
#          reservations_attended_martial_arts_count  \
# user_id
# 12                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 23                                            0.0
#
#          reservations_attended_pilates_count  \
# user_id
# 12                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 23                                       0.0
#
#          reservations_attended_rowing_count  \
# user_id
# 12                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 23                                      0.0
#
#          reservations_attended_strength_training_count  \
# user_id
# 12                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 23                                                 2.0
#
#          reservations_attended_yoga_count  reservations_attended_t1_count  \
# user_id
# 12                                    NaN                             NaN
# 14                                    NaN                             NaN
# 15                                    NaN                             NaN
# 16                                    NaN                             NaN
# 23                                    0.0                             0.0
#
#          reservations_attended_t2_count  reservations_attended_t3_count  \
# user_id
# 12                                  NaN                             NaN
# 14                                  NaN                             NaN
# 15                                  NaN                             NaN
# 16                                  NaN                             NaN
# 23                                  2.0                             0.0
#
#          reservations_attended_count  reservations_missed_count  \
# user_id
# 12                               NaN                        NaN
# 14                               NaN                        NaN
# 15                               NaN                        NaN
# 16                               NaN                        NaN
# 23                               2.0                        0.0
#
#          reservations_late_cancelled_count  \
# user_id
# 12                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 23                                     0.0
#
#          cost_of_all_reservations_in_usd_no_tax
# user_id
# 12                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 23                                         25.0

# %%
df = df.fillna(0)
df.head()
# Out:
#          is_converted  lead_created_month  lead_created_day_of_week  \
# user_id
# 12                  0                   5                         4
# 14                  0                   5                         5
# 15                  1                   6                         1
# 16                  1                   7                         3
# 23                  1                   6                         1
#
#          is_paidsocial_lead  is_organic_lead  lead_msa_id  is_seo_studios  \
# user_id
# 12                        0                1          1.0               0
# 14                        0                1          1.0               0
# 15                        0                1          1.0               0
# 16                        0                1          1.0               0
# 23                        0                1          1.0               0
#
#          is_inviteafriend  is_email  is_referral  is_paidsocial  \
# user_id
# 12                      0         0            0              0
# 14                      0         0            0              0
# 15                      0         0            0              0
# 16                      0         0            0              0
# 23                      0         0            0              0
#
#         marketing_channel  is_organic  user_acquisition_month  \
# user_id
# 12              Sell Page           1                     9.0
# 14              Sell Page           1                     9.0
# 15                 Mobile           1                     9.0
# 16              Sell Page           1                     8.0
# 23              Sell Page           0                     8.0
#
#          user_acquisition_day_of_week  promo_days  lead_to_promo_days  \
# user_id
# 12                                3.0         0.0                   0
# 14                                3.0         0.0                   0
# 15                                1.0         0.0                   0
# 16                                4.0         0.0                   0
# 23                                3.0        30.0                 429
#
#          is_three_studio_visits  is_two_studio_visits  is_four_studio_visits  \
# user_id
# 12                            1                     0                      0
# 14                            1                     0                      0
# 15                            0                     1                      0
# 16                            1                     0                      0
# 23                            0                     1                      0
#
#         acquisition_plan_category    zip  is_onboarded  user_country  \
# user_id
# 12               CP Complimentary  10001             1           1.0
# 14               CP Complimentary  10009             1           1.0
# 15                        CP Base  10003             1           1.0
# 16                   CP Unlimited      0             1           1.0
# 23                        CP Base  30363             1           1.0
#
#          user_msa_id promo_alias parent_promo promo_category  \
# user_id
# 12               1.0    no_promo     no_promo       no_promo
# 14               1.0    no_promo     no_promo       no_promo
# 15               1.0    no_promo     no_promo       no_promo
# 16               1.0    no_promo     no_promo       no_promo
# 23               1.0      aug1fb  dollarpromo          trial
#
#          is_commitment_plan  avg_class_rating  avg_days_from_booking_to_class  \
# user_id
# 12                      0.0               0.0                            0.00
# 14                      0.0               0.0                            0.00
# 15                      0.0               0.0                            0.00
# 16                      0.0               0.0                            0.00
# 23                      0.0               5.0                            1.25
#
#          avg_peak_classes  reservations_attended_barre_count  \
# user_id
# 12                   0.00                                0.0
# 14                   0.00                                0.0
# 15                   0.00                                0.0
# 16                   0.00                                0.0
# 23                   0.75                                0.0
#
#          reservations_attended_boxing_count  \
# user_id
# 12                                      0.0
# 14                                      0.0
# 15                                      0.0
# 16                                      0.0
# 23                                      0.0
#
#          reservations_attended_cycling_count  \
# user_id
# 12                                       0.0
# 14                                       0.0
# 15                                       0.0
# 16                                       0.0
# 23                                       0.0
#
#          reservations_attended_dance_count  reservations_attended_gym_count  \
# user_id
# 12                                     0.0                              0.0
# 14                                     0.0                              0.0
# 15                                     0.0                              0.0
# 16                                     0.0                              0.0
# 23                                     1.0                              0.0
#
#          reservations_attended_martial_arts_count  \
# user_id
# 12                                            0.0
# 14                                            0.0
# 15                                            0.0
# 16                                            0.0
# 23                                            0.0
#
#          reservations_attended_pilates_count  \
# user_id
# 12                                       0.0
# 14                                       0.0
# 15                                       0.0
# 16                                       0.0
# 23                                       0.0
#
#          reservations_attended_rowing_count  \
# user_id
# 12                                      0.0
# 14                                      0.0
# 15                                      0.0
# 16                                      0.0
# 23                                      0.0
#
#          reservations_attended_strength_training_count  \
# user_id
# 12                                                 0.0
# 14                                                 0.0
# 15                                                 0.0
# 16                                                 0.0
# 23                                                 2.0
#
#          reservations_attended_yoga_count  reservations_attended_t1_count  \
# user_id
# 12                                    0.0                             0.0
# 14                                    0.0                             0.0
# 15                                    0.0                             0.0
# 16                                    0.0                             0.0
# 23                                    0.0                             0.0
#
#          reservations_attended_t2_count  reservations_attended_t3_count  \
# user_id
# 12                                  0.0                             0.0
# 14                                  0.0                             0.0
# 15                                  0.0                             0.0
# 16                                  0.0                             0.0
# 23                                  2.0                             0.0
#
#          reservations_attended_count  reservations_missed_count  \
# user_id
# 12                               0.0                        0.0
# 14                               0.0                        0.0
# 15                               0.0                        0.0
# 16                               0.0                        0.0
# 23                               2.0                        0.0
#
#          reservations_late_cancelled_count  \
# user_id
# 12                                     0.0
# 14                                     0.0
# 15                                     0.0
# 16                                     0.0
# 23                                     0.0
#
#          cost_of_all_reservations_in_usd_no_tax
# user_id
# 12                                          0.0
# 14                                          0.0
# 15                                          0.0
# 16                                          0.0
# 23                                         25.0

# %%
df.drop(['marketing_channel', 'acquisition_plan_category','promo_alias','parent_promo','promo_category','zip'], axis=1, inplace=True)
df.head()
# Out:
#          is_converted  lead_created_month  lead_created_day_of_week  \
# user_id
# 12                  0                   5                         4
# 14                  0                   5                         5
# 15                  1                   6                         1
# 16                  1                   7                         3
# 23                  1                   6                         1
#
#          is_paidsocial_lead  is_organic_lead  lead_msa_id  is_seo_studios  \
# user_id
# 12                        0                1          1.0               0
# 14                        0                1          1.0               0
# 15                        0                1          1.0               0
# 16                        0                1          1.0               0
# 23                        0                1          1.0               0
#
#          is_inviteafriend  is_email  is_referral  is_paidsocial  is_organic  \
# user_id
# 12                      0         0            0              0           1
# 14                      0         0            0              0           1
# 15                      0         0            0              0           1
# 16                      0         0            0              0           1
# 23                      0         0            0              0           0
#
#          user_acquisition_month  user_acquisition_day_of_week  promo_days  \
# user_id
# 12                          9.0                           3.0         0.0
# 14                          9.0                           3.0         0.0
# 15                          9.0                           1.0         0.0
# 16                          8.0                           4.0         0.0
# 23                          8.0                           3.0        30.0
#
#          lead_to_promo_days  is_three_studio_visits  is_two_studio_visits  \
# user_id
# 12                        0                       1                     0
# 14                        0                       1                     0
# 15                        0                       0                     1
# 16                        0                       1                     0
# 23                      429                       0                     1
#
#          is_four_studio_visits  is_onboarded  user_country  user_msa_id  \
# user_id
# 12                           0             1           1.0          1.0
# 14                           0             1           1.0          1.0
# 15                           0             1           1.0          1.0
# 16                           0             1           1.0          1.0
# 23                           0             1           1.0          1.0
#
#          is_commitment_plan  avg_class_rating  avg_days_from_booking_to_class  \
# user_id
# 12                      0.0               0.0                            0.00
# 14                      0.0               0.0                            0.00
# 15                      0.0               0.0                            0.00
# 16                      0.0               0.0                            0.00
# 23                      0.0               5.0                            1.25
#
#          avg_peak_classes  reservations_attended_barre_count  \
# user_id
# 12                   0.00                                0.0
# 14                   0.00                                0.0
# 15                   0.00                                0.0
# 16                   0.00                                0.0
# 23                   0.75                                0.0
#
#          reservations_attended_boxing_count  \
# user_id
# 12                                      0.0
# 14                                      0.0
# 15                                      0.0
# 16                                      0.0
# 23                                      0.0
#
#          reservations_attended_cycling_count  \
# user_id
# 12                                       0.0
# 14                                       0.0
# 15                                       0.0
# 16                                       0.0
# 23                                       0.0
#
#          reservations_attended_dance_count  reservations_attended_gym_count  \
# user_id
# 12                                     0.0                              0.0
# 14                                     0.0                              0.0
# 15                                     0.0                              0.0
# 16                                     0.0                              0.0
# 23                                     1.0                              0.0
#
#          reservations_attended_martial_arts_count  \
# user_id
# 12                                            0.0
# 14                                            0.0
# 15                                            0.0
# 16                                            0.0
# 23                                            0.0
#
#          reservations_attended_pilates_count  \
# user_id
# 12                                       0.0
# 14                                       0.0
# 15                                       0.0
# 16                                       0.0
# 23                                       0.0
#
#          reservations_attended_rowing_count  \
# user_id
# 12                                      0.0
# 14                                      0.0
# 15                                      0.0
# 16                                      0.0
# 23                                      0.0
#
#          reservations_attended_strength_training_count  \
# user_id
# 12                                                 0.0
# 14                                                 0.0
# 15                                                 0.0
# 16                                                 0.0
# 23                                                 2.0
#
#          reservations_attended_yoga_count  reservations_attended_t1_count  \
# user_id
# 12                                    0.0                             0.0
# 14                                    0.0                             0.0
# 15                                    0.0                             0.0
# 16                                    0.0                             0.0
# 23                                    0.0                             0.0
#
#          reservations_attended_t2_count  reservations_attended_t3_count  \
# user_id
# 12                                  0.0                             0.0
# 14                                  0.0                             0.0
# 15                                  0.0                             0.0
# 16                                  0.0                             0.0
# 23                                  2.0                             0.0
#
#          reservations_attended_count  reservations_missed_count  \
# user_id
# 12                               0.0                        0.0
# 14                               0.0                        0.0
# 15                               0.0                        0.0
# 16                               0.0                        0.0
# 23                               2.0                        0.0
#
#          reservations_late_cancelled_count  \
# user_id
# 12                                     0.0
# 14                                     0.0
# 15                                     0.0
# 16                                     0.0
# 23                                     0.0
#
#          cost_of_all_reservations_in_usd_no_tax
# user_id
# 12                                          0.0
# 14                                          0.0
# 15                                          0.0
# 16                                          0.0
# 23                                         25.0

# %%
X = df.drop('is_converted', axis=1)
y = df['is_converted'].astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
def format_model_results(sklearn_model, X_train, X_test, y_train, y_test):
    # Get the model's class name (E.g. LogisticRegression, KNearestNeighbor, etc.) and store it to a string
    model_class_name = sklearn_model.__class__.__name__  
    
    y_test_pred   = sklearn_model.predict(X_test)
    y_test_pred_proba   = sklearn_model.predict_proba(X_test)
    y_train_pred  = sklearn_model.predict(X_train)

    accuracy_score  = metrics.accuracy_score(y_test, y_test_pred)
    precision_score = metrics.precision_score(y_test, y_test_pred, average='binary')
    recall_score    = metrics.recall_score(y_test, y_test_pred, average='binary')
    f1_score        = metrics.f1_score(y_test, y_test_pred, average='binary')
    f1_score_train  = metrics.f1_score(y_train, y_train_pred, average='binary')
    
    return pd.DataFrame({
            "Accuracy": accuracy_score, 
            "Precision": precision_score, 
            "Recall": recall_score, 
            "F1 score": f1_score, 
            "F1 score (train)": f1_score_train
        }, index=[model_class_name])

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()    
    
# Fits the model
dtc.fit(X, y)

# Helper function to visualize Decision Trees (creates a file tree.png)

from sklearn.tree import export_graphviz
from os import system 
def build_tree_image(dtc):
    dotfile = open("tree.dot", 'w')
    export_graphviz(dtc, out_file = dotfile, feature_names = X.columns)
    dotfile.close()
    system("dot -Tpng tree.dot -o tree.png")

# %%
from sklearn.model_selection import cross_val_score

# ... #

scores = cross_val_score(dtc, X, y, scoring='roc_auc', cv=5)
print('CV AUC {}, Average AUC {}'.format(scores, scores.mean()))
# Out:
# CV AUC [ 0.51077838  0.40001343  0.40326858  0.28254273  0.345221  ], Average AUC 0.388364822827

# %%
dtc = DecisionTreeClassifier(
                max_depth = 5,
                min_samples_leaf = 10)

dtc.fit(X, y)
build_tree_image(dtc)

# %%
max_depth_range = range(1,30)

RMSE_scores = []

for depth in max_depth_range:
    treereg = DecisionTreeClassifier(max_depth=depth)
    treescore = cross_val_score(treereg, X, y, cv=10, scoring='neg_mean_squared_error')
    rmse = np.mean(np.sqrt(-treescore))
    RMSE_scores.append(rmse)
print RMSE_scores
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-ee3ee362b3ef> in <module>()
#       5 for depth in max_depth_range:
#       6     treereg = DecisionTreeClassifier(max_depth=depth)
# ----> 7     treescore = cross_val_score(treereg, X, y, cv=10, scoring='neg_mean_squared_error')
#       8     rmse = np.mean(np.sqrt(-treescore))
#       9     RMSE_scores.append(rmse)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     138                                               train, test, verbose, None,
#     139                                               fit_params)
# --> 140                       for train, test in cv_iter)
#     141     return np.array(scores)[:, 0]
#     142
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                            self.min_impurity_split)
#     349
# --> 350         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     351
#     352         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
# plot max_depth (x-axis) versus RMSE (y-axis)
plt.pyplot.plot(max_depth_range, RMSE_scores)
plt.pyplot.xlabel('max_depth')
plt.pyplot.ylabel('RMSE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-a737f5d76df0> in <module>()
#       1 # plot max_depth (x-axis) versus RMSE (y-axis)
# ----> 2 plt.pyplot.plot(max_depth_range, RMSE_scores)
#       3 plt.pyplot.xlabel('max_depth')
#       4 plt.pyplot.ylabel('RMSE')
#
# AttributeError: 'module' object has no attribute 'pyplot'

# %%
format_model_results(dtc, X_train, X_test, y_train, y_test)

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=30)

rfr.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=30, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
format_model_results(rfr, X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-978e35a23348> in <module>()
# ----> 1 format_model_results(rfr, X_train, X_test, y_train, y_test)
#
# <ipython-input-146-a4260569aa1e> in format_model_results(sklearn_model, X_train, X_test, y_train, y_test)
#       4
#       5     y_test_pred   = sklearn_model.predict(X_test)
# ----> 6     y_test_pred_proba   = sklearn_model.predict_proba(X_test)
#       7     y_train_pred  = sklearn_model.predict(X_train)
#       8
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'predict_proba'

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators = 30)
    
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=30, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
format_model_results(rfc, X_train, X_test, y_train, y_test)
# Out:
#                         Accuracy  F1 score  F1 score (train)  Precision  \
# RandomForestClassifier  0.791542   0.84042           0.99615   0.837631
#
#                           Recall
# RandomForestClassifier  0.843228

# %%
features = X.columns
feature_importances = rfc.feature_importances_

features_rfc = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_rfc.sort_values('Importance Score', inplace=True, ascending=False)

print features_rfc
# Out:
#                                          Features  Importance Score
# 13                                     promo_days          0.132663
# 41         cost_of_all_reservations_in_usd_no_tax          0.075814
# 11                         user_acquisition_month          0.063448
# 38                    reservations_attended_count          0.060594
# 24                               avg_peak_classes          0.049947
# 23                 avg_days_from_booking_to_class          0.049685
# 0                              lead_created_month          0.047932
# 22                               avg_class_rating          0.040348
# 14                             lead_to_promo_days          0.034606
# 35                 reservations_attended_t1_count          0.034247
# 12                   user_acquisition_day_of_week          0.032571
# 4                                     lead_msa_id          0.032510
# 20                                    user_msa_id          0.032235
# 1                        lead_created_day_of_week          0.030112
# 10                                     is_organic          0.021313
# 36                 reservations_attended_t2_count          0.020529
# 33  reservations_attended_strength_training_count          0.019762
# 15                         is_three_studio_visits          0.019292
# 34               reservations_attended_yoga_count          0.017712
# 16                           is_two_studio_visits          0.016196
# 27            reservations_attended_cycling_count          0.015995
# 31            reservations_attended_pilates_count          0.015236
# 25              reservations_attended_barre_count          0.014891
# 37                 reservations_attended_t3_count          0.013961
# 18                                   is_onboarded          0.012045
# 9                                   is_paidsocial          0.011056
# 28              reservations_attended_dance_count          0.009750
# 3                                 is_organic_lead          0.008631
# 40              reservations_late_cancelled_count          0.008370
# 21                             is_commitment_plan          0.007416
# 26             reservations_attended_boxing_count          0.007040
# 8                                     is_referral          0.006592
# 39                      reservations_missed_count          0.006376
# 7                                        is_email          0.006054
# 19                                   user_country          0.004878
# 2                              is_paidsocial_lead          0.004498
# 32             reservations_attended_rowing_count          0.004117
# 30       reservations_attended_martial_arts_count          0.003789
# 29                reservations_attended_gym_count          0.003403
# 6                                is_inviteafriend          0.002380
# 17                          is_four_studio_visits          0.001296
# 5                                  is_seo_studios          0.000714

# %%
scores = cross_val_score(rfc, X, y, scoring='accuracy')
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))

for n_trees in range(1, 150, 30):
    model = RandomForestClassifier(n_estimators = n_trees)
    scores = cross_val_score(model, X, y, scoring='accuracy')
    print('n trees: {}, CV accuracy {}, Average accuracy {}'.format(n_trees, scores, scores.mean()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-162-1d81c3dd367f> in <module>()
# ----> 1 scores = cross_val_score(rfc, X, y, scoring='accuracy')
#       2 print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))
#       3
#       4 for n_trees in range(1, 150, 30):
#       5     model = RandomForestClassifier(n_estimators = n_trees)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     138                                               train, test, verbose, None,
#     139                                               fit_params)
# --> 140                       for train, test in cv_iter)
#     141     return np.array(scores)[:, 0]
#     142
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     236             estimator.fit(X_train, **fit_params)
#     237         else:
# --> 238             estimator.fit(X_train, y_train, **fit_params)
#     239
#     240     except Exception as e:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     324                     t, self, X, y, sample_weight, i, len(trees),
#     325                     verbose=self.verbose, class_weight=self.class_weight)
# --> 326                 for i, t in enumerate(trees))
#     327
#     328             # Collect newly grown trees
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     118             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     119
# --> 120         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     121     else:
#     122         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                            self.min_impurity_split)
#     349
# --> 350         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     351
#     352         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
# Feature Importance with Extra Trees Classifier
from sklearn.ensemble import ExtraTreesClassifier

# feature extraction
etc = ExtraTreesClassifier()
etc.fit(X, y)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(etc.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
print importances
importances.plot.bar()
# Out:
#                                                importance
# feature
# is_organic                                          0.091
# user_acquisition_month                              0.061
# promo_days                                          0.058
# avg_class_rating                                    0.050
# lead_created_month                                  0.047
# avg_peak_classes                                    0.046
# cost_of_all_reservations_in_usd_no_tax              0.037
# user_msa_id                                         0.034
# user_acquisition_day_of_week                        0.033
# is_onboarded                                        0.033
# is_three_studio_visits                              0.032
# lead_created_day_of_week                            0.031
# lead_msa_id                                         0.031
# avg_days_from_booking_to_class                      0.030
# lead_to_promo_days                                  0.028
# reservations_attended_count                         0.027
# reservations_attended_t1_count                      0.026
# is_two_studio_visits                                0.024
# reservations_attended_t2_count                      0.023
# reservations_attended_strength_training_count       0.023
# reservations_attended_yoga_count                    0.021
# reservations_attended_barre_count                   0.020
# reservations_attended_cycling_count                 0.020
# reservations_attended_pilates_count                 0.019
# reservations_attended_t3_count                      0.018
# is_paidsocial                                       0.018
# reservations_attended_dance_count                   0.014
# is_organic_lead                                     0.013
# reservations_late_cancelled_count                   0.012
# reservations_attended_boxing_count                  0.011
# reservations_missed_count                           0.010
# is_commitment_plan                                  0.009
# is_referral                                         0.007
# reservations_attended_rowing_count                  0.007
# is_email                                            0.006
# reservations_attended_martial_arts_count            0.006
# user_country                                        0.006
# reservations_attended_gym_count                     0.005
# is_inviteafriend                                    0.005
# is_paidsocial_lead                                  0.005
# is_four_studio_visits                               0.002
# is_seo_studios                                      0.001

# %%
format_model_results(etc, X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-424255eded2b> in <module>()
# ----> 1 format_model_results(etc, X_train, X_test, y_train, y_test)
#
# <ipython-input-146-a4260569aa1e> in format_model_results(sklearn_model, X_train, X_test, y_train, y_test)
#       3     model_class_name = sklearn_model.__class__.__name__
#       4
# ----> 5     y_test_pred   = sklearn_model.predict(X_test)
#       6     y_test_pred_proba   = sklearn_model.predict_proba(X_test)
#       7     y_train_pred  = sklearn_model.predict(X_train)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in predict(self, X)
#     532             The predicted classes.
#     533         """
# --> 534         proba = self.predict_proba(X)
#     535
#     536         if self.n_outputs_ == 1:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in predict_proba(self, X)
#     581             delayed(parallel_helper)(e, 'predict_proba', X,
#     582                                       check_input=False)
# --> 583             for e in self.estimators_)
#     584
#     585         # Reduce
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/utils/fixes.pyc in parallel_helper(obj, methodname, *args, **kwargs)
#     313 def parallel_helper(obj, methodname, *args, **kwargs):
#     314     """Helper to workaround Python 2 limitations of pickling instance methods"""
# --> 315     return getattr(obj, methodname)(*args, **kwargs)
#     316
#     317
#
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in predict_proba(self, X, check_input)
#     766         """
#     767         X = self._validate_X_predict(X, check_input)
# --> 768         proba = self.tree_.predict(X)
#     769
#     770         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
df2 = df[['is_converted','is_organic','promo_days','user_acquisition_month','cost_of_all_reservations_in_usd_no_tax','avg_class_rating','avg_peak_classes','lead_created_month','user_acquisition_day_of_week','avg_days_from_booking_to_class','reservations_attended_count']]

# %%
X = df2.drop('is_converted', axis=1)
y = df2['is_converted'].astype(int)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
dtc = DecisionTreeClassifier( max_depth = 5, min_samples_leaf = 10)

dtc.fit(X, y)
build_tree_image(dtc)

format_model_results(dtc, X_train, X_test, y_train, y_test)
# Out:
#                         Accuracy  F1 score  F1 score (train)  Precision  \
# DecisionTreeClassifier  0.749518  0.819539          0.819959   0.769923
#
#                          Recall
# DecisionTreeClassifier  0.87599

# %%
rfc = RandomForestClassifier(n_estimators = 30)
rfc.fit(X_train, y_train)

format_model_results(rfc, X_train, X_test, y_train, y_test)
# Out:
#                         Accuracy  F1 score  F1 score (train)  Precision  \
# RandomForestClassifier  0.765161   0.81971          0.986638     0.8172
#
#                           Recall
# RandomForestClassifier  0.822235

# %%
df3 = df[['is_converted','is_organic','promo_days','cost_of_all_reservations_in_usd_no_tax','avg_class_rating','avg_days_from_booking_to_class']]

X = df3.drop('is_converted', axis=1)
y = df3['is_converted'].astype(int)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
dtc = DecisionTreeClassifier( max_depth = 5, min_samples_leaf = 10)

dtc.fit(X, y)
build_tree_image(dtc)

format_model_results(dtc, X_train, X_test, y_train, y_test)

# %%
rfc = RandomForestClassifier(n_estimators = 30)
rfc.fit(X_train, y_train)

format_model_results(rfc, X_train, X_test, y_train, y_test)

# %%
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=555)
linreg = LinearRegression()
linreg.fit(X_train, y_train)
predict = linreg.predict(X_test)
print np.sqrt(metrics.mean_squared_error(y_test, predict))

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
# transform our training features
X_train_std = stdsc.fit_transform(X_train)
# transform the testing features in the same way
X_test_std = stdsc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(penalty='l2', C=10)

# %%
logreg.fit(X_train_std, y_train)
zip(X, logreg.coef_[0])

# %%
# class predictions (not predicted probabilities)
y_pred_class = logreg.predict(X_test_std)

# %%
# calculate classification accuracy
from sklearn import metrics
print metrics.accuracy_score(y_test, y_pred_class)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

#Run 10-fold Cross Val on regression model

linreg = LinearRegression()
scores = cross_val_score(linreg, X_scaled, y, cv=10, scoring='neg_mean_squared_error')
print np.sqrt(-scores).mean()

# %%
from sklearn.linear_model import RidgeCV

ridge = RidgeCV(scoring = 'neg_mean_squared_error', cv = 10)
ridge.fit(X_scaled, y)
ridge_scores = cross_val_score(linreg, X_scaled, y, cv=10, scoring='neg_mean_squared_error')
print np.sqrt(-ridge_scores).mean()
print ridge.alpha_ #model finds the best alpha value on its own

# %%
# 20 cross validation iterations with 30% test / 70% train
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)

from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
# transform our training features
X_train_std = stdsc.fit_transform(X_train)
# transform the testing features in the same way
X_test_std = stdsc.transform(X_test)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5,weights='uniform', p=2)

# %%
# search for an optimal value of K for KNN
k_range = list(range(1, 11))
k_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train_std, y_train, cv=10, scoring='accuracy')
    k_scores.append(scores.mean())
print(k_scores)
