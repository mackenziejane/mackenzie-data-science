# %% [markdown]
# # DS-NYC-45 | Final Project 3: Exploratory Data Analysis

# %% [markdown]
# Load python libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.notebook_repr_html', True)

# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('project_dataset', 'trialer_data.csv'))


df.head()
# Out:
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   users.user_id leads.lead_created_at_date leads.marketing_channel  \
# 0       1032299                     9/8/16                     RAF
# 1       1064327                    9/21/16                     RAF
# 2       1014475                    8/29/16                     RAF
# 3       1030044                     9/5/16                     RAF
# 4        944974                     8/9/16                     RAF
#
#   leads.utm_medium leads.utm_source        ...          \
# 0         referral        Friendbuy        ...
# 1         referral        Friendbuy        ...
# 2         referral        Friendbuy        ...
# 3         referral        Friendbuy        ...
# 4         referral        Friendbuy        ...
#
# ...

# %%
df.describe()
# Out:
# /Users/MacKenzie/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         leads.msa_id  user_cities.msa_id  users.is_converted
# count  567331.000000       575780.000000       575804.000000
# mean        9.773904            9.944463            0.654476
# std        11.588755           11.689437            0.475539
# min         1.000000            1.000000            0.000000
# 25%              NaN                 NaN            0.000000
# 50%              NaN                 NaN            1.000000
# 75%              NaN                 NaN            1.000000
# max        42.000000           42.000000            1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575804 entries, 0 to 575803
# Data columns (total 24 columns):
# users.user_id                              575804 non-null object
# leads.lead_created_at_date                 575804 non-null object
# leads.marketing_channel                    575804 non-null object
# leads.utm_medium                           117792 non-null object
# leads.utm_source                           118323 non-null object
# leads.msa_id                               567331 non-null float64
# users.marketing_channel                    575804 non-null object
# users.utm_medium                           361301 non-null object
# users.utm_source                           377090 non-null object
# users.is_organic                           575804 non-null object
# users.user_acquisition_date                575792 non-null object
# users.subscriber_conversion_date           376847 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# users.user_id                              0
# leads.lead_created_at_date                 0
# leads.marketing_channel                    0
# leads.utm_medium                      458012
# leads.utm_source                      457481
#                                        ...
# user_promotions.promo_alias                0
# user_promotions.parent_promo           31012
# user_promotions.promo_category             1
# user_promotions.is_commitment_plan         0
# users.is_converted                         0
# dtype: int64

# %%
## Histogram on converted subscribers
df['users.is_converted'].plot(kind='hist', bins=2)

# %%
df.replace(('Yes', 'No'), (1, 0), inplace=True)

# %%
sns.heatmap(df.corr())

# %%
with pd.option_context('display.max_rows', 999, 'display.max_columns', 3):
    print df
# Out:
#        users.user_id        ...         users.is_converted
# 0            1032299        ...                          0
# 1            1064327        ...                          1
# 2            1014475        ...                          0
# 3            1030044        ...                          1
# 4             944974        ...                          0
# 5             953937        ...                          1
# 6            1029293        ...                          0
# 7            1039449        ...                          0
# 8             840365        ...                          0
# 9             842968        ...                          1
# 10            847722        ...                          0
# 11            864527        ...                          1
# 12            872528        ...                          0
# 13            830984        ...                          0
# 14            837393        ...                          1
# ...

# %%
pd.crosstab(df['leads.marketing_channel'],df['users.is_converted'], margins = True)
# Out:
# users.is_converted            0       1     All
# leads.marketing_channel
# Direct Mail                 583     509    1092
# Display                     465    1011    1476
# Email                       657    1703    2360
# Mobile                     1022    5994    7016
# Other Paid                  555    2235    2790
# ...                         ...     ...     ...
# RAF                         412     787    1199
# SEM                        8457   27273   35730
# SEO Studios                 698     720    1418
# Sell Page                156806  303275  460081
# All                      198954  376850  575804
#
# [12 rows x 3 columns]

# %%
df['leads.marketing_channel'].value_counts().plot(kind='bar')

# %%
conv_leads_marketing_channel = df[['leads.marketing_channel','users.is_converted']]
conv_leads_marketing_channel = conv_leads_marketing_channel[(conv_leads_marketing_channel['users.is_converted']==1)]
conv_leads_marketing_channel['leads.marketing_channel'].value_counts().plot(kind='bar')

# %%
pd.crosstab(df['users.marketing_channel'],df['users.is_converted'], margins = True)
# Out:
# users.is_converted            0       1     All
# users.marketing_channel
# Direct Mail                3570    3278    6848
# Display                    1080    1449    2529
# Email                     29693   68129   97822
# IAF                       11100    4003   15103
# Mobile                       93   24375   24468
# ...                         ...     ...     ...
# RAF                       10485   22229   32714
# SEM                       20762   26279   47041
# SEO Studios                1169    1240    2409
# Sell Page                 44141  152921  197062
# All                      198954  376850  575804
#
# [13 rows x 3 columns]

# %%
df['users.marketing_channel'].value_counts().plot(kind='bar')

# %%
conv_users_marketing_channel = df[['users.marketing_channel','users.is_converted']]
conv_users_marketing_channel = conv_users_marketing_channel[(conv_users_marketing_channel['users.is_converted']==1)]
conv_users_marketing_channel['users.marketing_channel'].value_counts().plot(kind='bar')
